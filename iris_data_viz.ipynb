# %% [markdown]
# <a href="https://colab.research.google.com/github/ShibleNK/ml-practice/blob/main/iris_data_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
correlation = iris.drop('species', axis=1).corr()

# %%
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.drop('species', axis=1).corr(), cmap= 'coolwarm', annot=True),
# Out:
# (<Axes: >,)

# %%
sns.set(style="whitegrid", color_codes=True) # change style

# %%
sns.lmplot(x="sepal_length", y="petal_length", hue="species", data=iris, \
           palette="Set1", markers=["o", "s", "D"])

# %%
sns.lmplot(x="sepal_length", y="petal_length", hue="species", data=iris, \
           palette="Set1", fit_reg=False, markers=["o", "s", "D"])

# %%
sns.pairplot(iris, size=5, vars=["sepal_length", "petal_length"], \
             markers=["o", "s", "D"], hue="species")
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(iris, markers=["o", "s", "D"], hue="species")

# %%
sns.boxplot(data = iris, orient = "h")
# Out:
# <Axes: >

# %%
iris["ID"] = iris.index
iris["ration"] = iris["sepal_length"]/iris["sepal_width"]
sns.lmplot(x="ID", y="ration", data=iris, \
           hue="species", markers=["o", "s", "D"], fit_reg=False, legend=True)

# %%
sns.stripplot(x="species", y = "sepal_length", data= iris, jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.swarmplot(x="species", y = "sepal_length", data= iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>
